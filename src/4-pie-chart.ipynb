# %% [markdown]
# ### Exercise 4: Pie Chart with Percentages

# %%
# TASK: Create a pie chart with the following data: labels = ['Python', 'Java', 'C++', 'JavaScript'] and sizes = [40, 25, 20, 15].
# Display the percentages on the chart using autopct.

# %%
import matplotlib.pyplot as plt

# %%
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]
colors = ['blue', 'red', 'green', 'orange']

# %%
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x780e1c3ddbd0>,
#   <matplotlib.patches.Wedge at 0x780e1c3ddb10>,
#   <matplotlib.patches.Wedge at 0x780e1c3def20>,
#   <matplotlib.patches.Wedge at 0x780e1c3df970>],
#  [Text(-0.9328528920784657, -0.5829112125708705, 'Python'),
#   Text(0.9428842451175865, -0.5665415256704835, 'Java'),
#   Text(0.7070659684717128, 0.8426492249027225, 'C++'),
#   Text(-0.4298051780683124, 1.0125549411788313, 'JavaScript')],
#  [Text(-0.5088288502246175, -0.3179515704932021, '40.0%'),
#   Text(0.5143004973368653, -0.3090226503657183, '25.0%'),
#   Text(0.385672346439116, 0.45962684994693953, '20.0%'),
#   Text(-0.2344391880372613, 0.5523026951884533, '15.0%')])

# %%
plt.title("Programming Language Popularity")
# Out:
# Text(0.5, 1.0, 'Programming Language Popularity')

# %%
plt.show()
